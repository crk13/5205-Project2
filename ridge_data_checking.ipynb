# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, MaxAbsScaler
from sklearn.pipeline import Pipeline
import joblib

# %%
file_path = "data/final_df.csv"
df_ori = pd.read_csv(file_path)

df_ori['datetime'] = pd.to_datetime(df_ori['datetime'])
df_ori = df_ori.sort_values(by=['datetime'])
df_ori = df_ori.reset_index(drop=True)
df_ori.head()
# Out:
#              datetime symbol  dow_0  dow_1  dow_2  dow_3  dow_4  dow_5  \
# 0 2024-04-30 12:50:00   AMAT      0      1      0      0      0      0
# 1 2024-04-30 12:50:00   AVGO      0      1      0      0      0      0
# 2 2024-04-30 12:50:00     MU      0      1      0      0      0      0
# 3 2024-04-30 12:50:00    AMD      0      1      0      0      0      0
# 4 2024-04-30 12:50:00   NVDA      0      1      0      0      0      0
#
#    f_minsin  f_mincos  ...  div_amount_iqr_outlier  shares_out_nonpos_flag  \
# 0  -0.94693  0.321439  ...                       0                       0
# 1  -0.94693  0.321439  ...                       0                       0
# 2  -0.94693  0.321439  ...                       0                       0
# 3  -0.94693  0.321439  ...                       0                       0
# 4  -0.94693  0.321439  ...                       0                       0
#
#    split_nonpos_flag  shares_out  log_shares_out  eps_surp_pct_final  \
# 0                  1   830897024       20.538016                0.00
# 1                  1   465308000       19.958210                0.00
# 2                  1  1107369984       20.825254                0.00
# 3                  1  1616140032       21.203306                2.04
# 4                  1  2500000000       21.639557                0.00
#
#    div_amount  log_shares_out_iqr_outlier  eps_estimate_rz_8  eps_actual
# 0         0.0                           0                0.0        0.00
# 1         0.0                           0                0.0        0.00
# 2         0.0                           0                0.0        0.00
# 3         0.0                           0                0.0        0.62
# 4         0.0                           0                0.0        0.00
#
# [5 rows x 167 columns]

# %%
df = df_ori.copy()

# %%
df['y_target'] = df.groupby(['symbol', df['datetime'].dt.date])['fz_lret_1_rolling'].shift(-1)
df[["datetime", "symbol", "y_target"]]
# Out:
#                   datetime symbol  y_target
# 0      2024-04-30 12:50:00   AMAT -0.169358
# 1      2024-04-30 12:50:00   AVGO -0.620658
# 2      2024-04-30 12:50:00     MU  2.225385
# 3      2024-04-30 12:50:00    AMD  0.932911
# 4      2024-04-30 12:50:00   NVDA -1.457090
# ...                    ...    ...       ...
# 324895 2025-10-28 15:59:00     MU       NaN
# 324896 2025-10-28 15:59:00    AMD       NaN
# 324897 2025-10-28 15:59:00   AMAT       NaN
# 324898 2025-10-28 15:59:00   AVGO       NaN
# 324899 2025-10-28 15:59:00   NVDA       NaN
#
# [324900 rows x 3 columns]

# %%
features_to_drop = ['y_target', 'fz_lret_1_rolling','year', 'month', 'day', 'minute', 'minute_of_day', 'dow_5', 'dow_6']

all_cols_set = set(df.columns)
drop_cols_set = set(features_to_drop)
keep_cols_set = all_cols_set - drop_cols_set - {'datetime', 'symbol'}
feature_cols = sorted(list(keep_cols_set))

df_model = df.dropna(subset=['y_target'])
df_model[["datetime", "symbol", 'fz_lret_1_rolling', "y_target"]]
# Out:
#                   datetime symbol  fz_lret_1_rolling  y_target
# 0      2024-04-30 12:50:00   AMAT           0.974098 -0.169358
# 1      2024-04-30 12:50:00   AVGO           1.712327 -0.620658
# 2      2024-04-30 12:50:00     MU           2.725425  2.225385
# 3      2024-04-30 12:50:00    AMD           4.291575  0.932911
# 4      2024-04-30 12:50:00   NVDA           2.057602 -1.457090
# ...                    ...    ...                ...       ...
# 324890 2025-10-28 15:58:00    AMD          -2.102746 -3.877713
# 324891 2025-10-28 15:58:00     MU           0.872353 -0.494423
# 324892 2025-10-28 15:58:00   AVGO           0.209849  1.057159
# 324893 2025-10-28 15:58:00   NVDA           0.363492 -0.542356
# 324894 2025-10-28 15:58:00   AMAT          -2.057879 -0.286397
#
# [323190 rows x 4 columns]

# %%
try:
    # --- 1. 检查 NaN (空值) ---
    nan_counts = df_model.isnull().sum().sum()
    print("--- 检查 NaN (空值) ---")
    if nan_counts == 0:
        print("✅ 恭喜！'df_model' 中没有任何 NaN 值。")
    else:
        print(f"⚠️ 警告！'df_model' 中总共发现 {nan_counts} 个 NaN 值。")

    # --- 2. 检查 ±Inf (无穷大) ---
    numeric_cols = df_model.select_dtypes(include=[np.number]).columns
    pos_inf_count = np.isinf(df_model[numeric_cols]).values.sum()
    neg_inf_count = np.isneginf(df_model[numeric_cols]).values.sum()

    print("\n--- 检查 ±Inf (无穷大) ---")
    if pos_inf_count == 0 and neg_inf_count == 0:
        print("✅ 恭喜！'df_model' 中没有任何 Inf 值。")
    else:
        print(f"⚠️ 警告！发现 {pos_inf_count} 个 +Inf 值。")
        print(f"⚠️ 警告！发现 {neg_inf_count} 个 -Inf 值。")

    # --- 3. 检查极端大值 (描述性统计) ---
    print("\n--- 检查极端大值 (描述性统计) ---")
    
    # (!! 这是修复你问题的代码 !!)
    # 我们设置 'display.float_format' 来禁用科学记数法
    # 我们设置 'display.max_rows' 来显示所有列
    
    # 获取数值型列
    numeric_cols_for_describe = df_model.select_dtypes(include=[np.number]).columns
    
    with pd.option_context(
        'display.float_format', '{:.4f}'.format, # 格式化为 4 位小数
        'display.max_rows', None                 # 显示所有行 (所有特征)
    ):
        print("（已禁用科学记数法并显示所有特征）")
        
        # .T (转置) 使其更易于阅读
        description = df_model[numeric_cols_for_describe].describe(percentiles=[.01, .25, .5, .75, .99]).T
        
        # 打印描述性统计
        print(description)

except NameError:
    print("\n*** 错误: 'df_model' 未定义。***")
    print("请确保你已经运行了之前的单元格来创建 'df_model'。")
except Exception as e:
    print(f"\n*** 检查时出错: {e} ***")
# Out:
# --- 检查 NaN (空值) ---
# ✅ 恭喜！'df_model' 中没有任何 NaN 值。
#
# --- 检查 ±Inf (无穷大) ---
# ✅ 恭喜！'df_model' 中没有任何 Inf 值。
#
# --- 检查极端大值 (描述性统计) ---
# （已禁用科学记数法并显示所有特征）
#                                      count  \
# dow_0                          323190.0000
# dow_1                          323190.0000
# dow_2                          323190.0000
# dow_3                          323190.0000
# dow_4                          323190.0000
# dow_5                          323190.0000
# f_minsin                       323190.0000
# f_mincos                       323190.0000
# close                          323190.0000
# f_volu_z_15_clipped            323190.0000
# f_volu_z_30_clipped            323190.0000
# f_volu_z_5_clipped             323190.0000
# f_volu_z_60_clipped            323190.0000
# f_volume_norm                  323190.0000
# fz_bb_pos                      323190.0000
# fz_dev_close_ema20             323190.0000
# fz_dev_close_ema200            323190.0000
# fz_dev_close_vwap_15           323190.0000
# fz_dev_close_vwap_60           323190.0000
# fz_dev_tp_ema20                323190.0000
# fz_hl_over_atr20               323190.0000
# fz_hl_range_pct                323190.0000
# fz_lret_15_rolling             323190.0000
# fz_lret_1_rolling              323190.0000
# fz_lret_30_rolling             323190.0000
# fz_lret_5_rolling              323190.0000
# fz_lret_60_rolling             323190.0000
# fz_macd_hist                   323190.0000
# fz_oc_change_pct               323190.0000
# fz_rsi_pos                     323190.0000
# fz_spill_AMAT_lret_lag1        323190.0000
# fz_spill_AMAT_lret_lag2        323190.0000
# fz_spill_AMAT_lret_lag3        323190.0000
# fz_spill_AMAT_lret_lag4        323190.0000
# fz_spill_AMAT_lret_lag5        323190.0000
# fz_spill_AMD_lret_lag1         323190.0000
# fz_spill_AMD_lret_lag2         323190.0000
# fz_spill_AMD_lret_lag3         323190.0000
# fz_spill_AMD_lret_lag4         323190.0000
# fz_spill_AMD_lret_lag5         323190.0000
# fz_spill_AVGO_lret_lag1        323190.0000
# fz_spill_AVGO_lret_lag2        323190.0000
# fz_spill_AVGO_lret_lag3        323190.0000
# fz_spill_AVGO_lret_lag4        323190.0000
# fz_spill_AVGO_lret_lag5        323190.0000
# fz_spill_MU_lret_lag1          323190.0000
# fz_spill_MU_lret_lag2          323190.0000
# fz_spill_MU_lret_lag3          323190.0000
# fz_spill_MU_lret_lag4          323190.0000
# fz_spill_MU_lret_lag5          323190.0000
# fz_spill_NVDA_lret_lag1        323190.0000
# fz_spill_NVDA_lret_lag2        323190.0000
# fz_spill_NVDA_lret_lag3        323190.0000
# fz_spill_NVDA_lret_lag4        323190.0000
# fz_spill_NVDA_lret_lag5        323190.0000
# fz_vol_15                      323190.0000
# fz_vol_30                      323190.0000
# fz_vol_5                       323190.0000
# fz_vol_60                      323190.0000
# fz_vol_ratio_15                323190.0000
# fz_vol_ratio_30                323190.0000
# fz_vol_ratio_5                 323190.0000
# fz_vol_ratio_60                323190.0000
# high                           323190.0000
# hl_range                       323190.0000
# low                            323190.0000
# oc_change                      323190.0000
# open                           323190.0000
# rsi_14_clip                    323190.0000
# vol_15                         323190.0000
# vol_30                         323190.0000
# vol_5                          323190.0000
# vol_60                         323190.0000
# volu_z_15                      323190.0000
# volu_z_30                      323190.0000
# volu_z_5                       323190.0000
# volu_z_60                      323190.0000
# volume                         323190.0000
# year                           323190.0000
# month                          323190.0000
# day                            323190.0000
# overnight_n_rs                 323190.0000
# mins_since_last_news_rs        323190.0000
# tone_mean_ewm_hl15             323190.0000
# overnight_tone_sum_rs          323190.0000
# minute_cos                     323190.0000
# n_news_ewm_hl15_rs             323190.0000
# cnt_15m                        323190.0000
# tone_ewm15                     323190.0000
# morning_n                      323190.0000
# minute_sin                     323190.0000
# dow_6                          323190.0000
# n_news_ewm_hl5_rs              323190.0000
# overnight_tone_sum             323190.0000
# morning_tone_sum               323190.0000
# cnt_30m                        323190.0000
# n_news_ewm_hl15                323190.0000
# tone_mean_delta_rs             323190.0000
# morning_tone_mean              323190.0000
# morning_source_div_rs          323190.0000
# tone_ewm30                     323190.0000
# morning_tone_sum_rs            323190.0000
# mins_since_last_news           323190.0000
# tone_mean_ewm_hl15_rs          323190.0000
# overnight_n                    323190.0000
# cnt_5m                         323190.0000
# overnight_tone_mean_rs         323190.0000
# n_news_ewm_hl5                 323190.0000
# morning_source_div             323190.0000
# tone_ewm30_rs                  323190.0000
# overnight_source_div_rs        323190.0000
# cnt_60m                        323190.0000
# morning_n_rs                   323190.0000
# overnight_tone_mean            323190.0000
# overnight_source_div           323190.0000
# has_news                       323190.0000
# morning_tone_mean_rs           323190.0000
# minute_of_day_1based           323190.0000
# tone_ewm15_rs                  323190.0000
# tone_mean_delta                323190.0000
# surprise_tone_mean             323190.0000
# abs_tone_mean                  323190.0000
# n_pos_raw                      323190.0000
# tone_sum                       323190.0000
# n_news                         323190.0000
# tone_mean                      323190.0000
# tone_sum_slog                  323190.0000
# cnt_60m_rs                     323190.0000
# eps_actual_iqr_outlier         323190.0000
# shares_out_roll_mean_252       323190.0000
# dividend                       323190.0000
# eps_estimate_iqr_outlier       323190.0000
# div_amount_rz_8                323190.0000
# eps_actual_rz_8                323190.0000
# eps_estimate                   323190.0000
# 5d_before_earnings_flag        323190.0000
# shares_out_ffill               323190.0000
# eps_surp_pct                   323190.0000
# split_flag                     323190.0000
# dividend_iqr_outlier           323190.0000
# earnings_flag                  323190.0000
# shares_out_iqr_outlier         323190.0000
# split_mult_iqr_outlier         323190.0000
# eps_surp_rz_8                  323190.0000
# shares_out_roll_z_252          323190.0000
# split_ratio_iqr_outlier        323190.0000
# div_event_flag                 323190.0000
# eps_surp_winsor_iqr_outlier    323190.0000
# shares_out_roll_std_252        323190.0000
# split_mult                     323190.0000
# split_ratio                    323190.0000
# eps_surp_pct_final_iqr_outlier 323190.0000
# eps_surp_winsor                323190.0000
# div_negative_flag              323190.0000
# eps_surp_pct_calc              323190.0000
# div_amount_iqr_outlier         323190.0000
# shares_out_nonpos_flag         323190.0000
# split_nonpos_flag              323190.0000
# shares_out                     323190.0000
# log_shares_out                 323190.0000
# eps_surp_pct_final             323190.0000
# div_amount                     323190.0000
# log_shares_out_iqr_outlier     323190.0000
# eps_estimate_rz_8              323190.0000
# eps_actual                     323190.0000
# y_target                       323190.0000
#
#                                                                              mean  \
# dow_0                                                                      0.1901
# dow_1                                                                      0.2105
# dow_2                                                                      0.1988
# dow_3                                                                      0.1988
# dow_4                                                                      0.2018
# dow_5                                                                      0.0000
# f_minsin                                                                  -0.5751
# f_mincos                                                                  -0.7794
# close                                                                    158.6059
# f_volu_z_15_clipped                                                        0.1450
# f_volu_z_30_clipped                                                        0.2133
# f_volu_z_5_clipped                                                         0.0543
# f_volu_z_60_clipped                                                        0.2553
# f_volume_norm                                                              0.0522
# fz_bb_pos                                                                 -0.0322
# fz_dev_close_ema20                                                        -0.0437
# fz_dev_close_ema200                                                       -0.1027
# fz_dev_close_vwap_15                                                      -0.0221
# fz_dev_close_vwap_60                                                      -0.0488
# fz_dev_tp_ema20                                                           -0.0465
# fz_hl_over_atr20                                                           0.5337
# fz_hl_range_pct                                                           -0.0624
# fz_lret_15_rolling                                                        -0.0241
# fz_lret_1_rolling                                                         -0.0168
# fz_lret_30_rolling                                                 -21569022.0663
# fz_lret_5_rolling                                                          0.0053
# fz_lret_60_rolling                                                 -41033333.4306
# fz_macd_hist                                                               0.0671
# fz_oc_change_pct                                                           0.0070
# fz_rsi_pos                                                                -0.0244
# fz_spill_AMAT_lret_lag1                                                    0.0197
# fz_spill_AMAT_lret_lag2                                                   -0.0031
# fz_spill_AMAT_lret_lag3                                                   -0.0012
# fz_spill_AMAT_lret_lag4                                                    0.0069
# fz_spill_AMAT_lret_lag5                                                    0.0113
# fz_spill_AMD_lret_lag1                                                    -0.0046
# fz_spill_AMD_lret_lag2                                                    -0.0064
# fz_spill_AMD_lret_lag3                                                    -0.0059
# fz_spill_AMD_lret_lag4                                                    -0.0081
# fz_spill_AMD_lret_lag5                                                    -0.0074
# fz_spill_AVGO_lret_lag1                                                    0.0021
# fz_spill_AVGO_lret_lag2                                                   -0.0002
# fz_spill_AVGO_lret_lag3                                                    0.0038
# fz_spill_AVGO_lret_lag4                                                    0.0047
# fz_spill_AVGO_lret_lag5                                                    0.0070
# fz_spill_MU_lret_lag1                                                      0.0071
# fz_spill_MU_lret_lag2                                                     -0.0137
# fz_spill_MU_lret_lag3                                                     -0.0045
# fz_spill_MU_lret_lag4                                                     -0.0069
# fz_spill_MU_lret_lag5                                                     -0.0014
# fz_spill_NVDA_lret_lag1                                                    0.0031
# fz_spill_NVDA_lret_lag2                                                   -0.0109
# fz_spill_NVDA_lret_lag3                                                   -0.0081
# fz_spill_NVDA_lret_lag4                                                   -0.0060
# fz_spill_NVDA_lret_lag5                                                   -0.0078
# fz_vol_15                                                                  0.2328
# fz_vol_30                                                                  0.2352
# fz_vol_5                                                                   0.2158
# fz_vol_60                                                                  0.2299
# fz_vol_ratio_15                                                            1.2121
# fz_vol_ratio_30                                                            1.6744
# fz_vol_ratio_5                                                             0.6147
# fz_vol_ratio_60                                                            2.2087
# high                                                                     158.6884
# hl_range                                                                   0.1674
# low                                                                      158.5210
# oc_change                                                                  0.0005
# open                                                                     158.6053
# rsi_14_clip                                                               50.3046
# vol_15                                                                     0.0612
# vol_30                                                                     0.0436
# vol_5                                                                      0.1018
# vol_60                                                                     0.0312
# volu_z_15                                                                  0.1450
# volu_z_30                                                                  0.2145
# volu_z_5                                                                   0.0543
# volu_z_60                                                                  0.2775
# volume                                                                149179.4018
# year                                                                    2024.5468
# month                                                                      6.8684
# day                                                                       15.7895
# overnight_n_rs                                                             0.0285
# mins_since_last_news_rs                                                    0.1154
# tone_mean_ewm_hl15                                                         0.0061
# overnight_tone_sum_rs                                                     -0.1030
# minute_cos                                                                -0.7863
# n_news_ewm_hl15_rs                                                     18383.4236
# cnt_15m                                                                    0.2476
# tone_ewm15                                                                 0.0059
# morning_n                                                                  4.5667
# minute_sin                                                                -0.5713
# dow_6                                                                      0.0000
# n_news_ewm_hl5_rs                                       10534441574176952320.0000
# overnight_tone_sum                                                        11.2612
# morning_tone_sum                                                           3.8669
# cnt_30m                                                                    0.4995
# n_news_ewm_hl15                                                            0.0168
# tone_mean_delta_rs                                                        -0.0000
# morning_tone_mean                                                          0.5320
# morning_source_div_rs                                                      0.0432
# tone_ewm30                                                                 0.0060
# morning_tone_sum_rs                                                        0.1630
# mins_since_last_news                                                  191699.3435
# tone_mean_ewm_hl15_rs                                     492643111190852672.0000
# overnight_n                                                               14.5930
# cnt_5m                                                                     0.0792
# overnight_tone_mean_rs                                                    -0.0962
# n_news_ewm_hl5                                                             0.0163
# morning_source_div                                                         1.3468
# tone_ewm30_rs                                   2648631794982914577550802944.0000
# overnight_source_div_rs                                                   -0.0186
# cnt_60m                                                                    1.0209
# morning_n_rs                                                               0.0769
# overnight_tone_mean                                                        0.5968
# overnight_source_div                                                       2.2544
# has_news                                                                   0.0087
# morning_tone_mean_rs                                                       0.3527
# minute_of_day_1based                                                     865.0000
# tone_ewm15_rs                  15983941967733222437347951087926096750453180464...
# tone_mean_delta                                                           -0.0000
# surprise_tone_mean                                                         0.0053
# abs_tone_mean                                                              0.0113
# n_pos_raw                                                                  0.0113
# tone_sum                                                                   0.0104
# n_news                                                                     0.0155
# tone_mean                                                                  0.0057
# tone_sum_slog                                                              0.0044
# cnt_60m_rs                                                                 0.1302
# eps_actual_iqr_outlier                                                     0.0000
# shares_out_roll_mean_252                                                  21.4444
# dividend                                                                   0.0039
# eps_estimate_iqr_outlier                                                   0.0000
# div_amount_rz_8                                                            0.0004
# eps_actual_rz_8                                                            0.0059
# eps_estimate                                                               0.0235
# 5d_before_earnings_flag                                                    0.2544
# shares_out_ffill                                                  6144025019.0579
# eps_surp_pct                                                               0.0874
# split_flag                                                                 1.0000
# dividend_iqr_outlier                                                       0.0129
# earnings_flag                                                              0.0175
# shares_out_iqr_outlier                                                     0.0398
# split_mult_iqr_outlier                                                     0.0012
# eps_surp_rz_8                                                              0.0001
# shares_out_roll_z_252                                                      0.2422
# split_ratio_iqr_outlier                                                    0.0012
# div_event_flag                                                             0.0140
# eps_surp_winsor_iqr_outlier                                                0.0006
# shares_out_roll_std_252                                                    0.1776
# split_mult                                                                 0.0117
# split_ratio                                                                0.0117
# eps_surp_pct_final_iqr_outlier                                             0.0006
# eps_surp_winsor                                                            0.0874
# div_negative_flag                                                          0.0000
# eps_surp_pct_calc                                                          0.0870
# div_amount_iqr_outlier                                                     0.0129
# shares_out_nonpos_flag                                                     0.0000
# split_nonpos_flag                                                          0.9988
# shares_out                                                        6144025019.0579
# log_shares_out                                                            21.6568
# eps_surp_pct_final                                                         0.0874
# div_amount                                                                 0.0039
# log_shares_out_iqr_outlier                                                 0.0392
# eps_estimate_rz_8                                                          0.0054
# eps_actual                                                                 0.0246
# y_target                                                                  -0.0183
#
#                                                                               std  \
# dow_0                                                                      0.3923
# dow_1                                                                      0.4077
# dow_2                                                                      0.3991
# dow_3                                                                      0.3991
# dow_4                                                                      0.4013
# dow_5                                                                      0.0000
# f_minsin                                                                   0.1901
# f_mincos                                                                   0.1602
# close                                                                     53.0292
# f_volu_z_15_clipped                                                        1.0751
# f_volu_z_30_clipped                                                        1.1742
# f_volu_z_5_clipped                                                         0.9236
# f_volu_z_60_clipped                                                        1.2225
# f_volume_norm                                                              1.1984
# fz_bb_pos                                                                  1.8375
# fz_dev_close_ema20                                                         2.5087
# fz_dev_close_ema200                                                        2.3380
# fz_dev_close_vwap_15                                                       2.3586
# fz_dev_close_vwap_60                                                       2.2525
# fz_dev_tp_ema20                                                            2.4990
# fz_hl_over_atr20                                                           2.7190
# fz_hl_range_pct                                                            2.5127
# fz_lret_15_rolling                                                         2.5550
# fz_lret_1_rolling                                                          2.4270
# fz_lret_30_rolling                                                1125619429.2364
# fz_lret_5_rolling                                                          2.4559
# fz_lret_60_rolling                                                1481203819.5381
# fz_macd_hist                                                               2.3087
# fz_oc_change_pct                                                           2.3645
# fz_rsi_pos                                                                 2.1411
# fz_spill_AMAT_lret_lag1                                                    1.1603
# fz_spill_AMAT_lret_lag2                                                    1.0937
# fz_spill_AMAT_lret_lag3                                                    1.1050
# fz_spill_AMAT_lret_lag4                                                    1.0937
# fz_spill_AMAT_lret_lag5                                                    1.1105
# fz_spill_AMD_lret_lag1                                                     1.0719
# fz_spill_AMD_lret_lag2                                                     1.0684
# fz_spill_AMD_lret_lag3                                                     1.0680
# fz_spill_AMD_lret_lag4                                                     1.0584
# fz_spill_AMD_lret_lag5                                                     1.0651
# fz_spill_AVGO_lret_lag1                                                    1.1010
# fz_spill_AVGO_lret_lag2                                                    1.1012
# fz_spill_AVGO_lret_lag3                                                    1.1098
# fz_spill_AVGO_lret_lag4                                                    1.0899
# fz_spill_AVGO_lret_lag5                                                    1.0822
# fz_spill_MU_lret_lag1                                                      1.0922
# fz_spill_MU_lret_lag2                                                      1.0730
# fz_spill_MU_lret_lag3                                                      1.0734
# fz_spill_MU_lret_lag4                                                      1.0627
# fz_spill_MU_lret_lag5                                                      1.0794
# fz_spill_NVDA_lret_lag1                                                    1.0857
# fz_spill_NVDA_lret_lag2                                                    1.0702
# fz_spill_NVDA_lret_lag3                                                    1.0713
# fz_spill_NVDA_lret_lag4                                                    1.0658
# fz_spill_NVDA_lret_lag5                                                    1.0691
# fz_vol_15                                                                  1.6676
# fz_vol_30                                                                  2.0136
# fz_vol_5                                                                   1.3480
# fz_vol_60                                                                  2.6279
# fz_vol_ratio_15                                                            4.0488
# fz_vol_ratio_30                                                            5.2925
# fz_vol_ratio_5                                                             2.8601
# fz_vol_ratio_60                                                            7.1917
# high                                                                      53.0476
# hl_range                                                                   0.1374
# low                                                                       53.0115
# oc_change                                                                  0.1370
# open                                                                      53.0295
# rsi_14_clip                                                               11.5796
# vol_15                                                                     0.0394
# vol_30                                                                     0.0265
# vol_5                                                                      0.0778
# vol_60                                                                     0.0180
# volu_z_15                                                                  1.0751
# volu_z_30                                                                  1.1783
# volu_z_5                                                                   0.9236
# volu_z_60                                                                  1.3136
# volume                                                                657263.5955
# year                                                                       0.4978
# month                                                                      2.9986
# day                                                                        8.6891
# overnight_n_rs                                                             1.1051
# mins_since_last_news_rs                                                    1.9093
# tone_mean_ewm_hl15                                                         0.0252
# overnight_tone_sum_rs                                                     22.0056
# minute_cos                                                                 0.1390
# n_news_ewm_hl15_rs                                                    753306.7570
# cnt_15m                                                                    0.8090
# tone_ewm15                                                                 0.0407
# morning_n                                                                  8.0843
# minute_sin                                                                 0.1899
# dow_6                                                                      0.0000
# n_news_ewm_hl5_rs                                      806368153425824579584.0000
# overnight_tone_sum                                                        22.0998
# morning_tone_sum                                                           8.0611
# cnt_30m                                                                    1.2813
# n_news_ewm_hl15                                                            0.0391
# tone_mean_delta_rs                                                         1.9199
# morning_tone_mean                                                          1.0661
# morning_source_div_rs                                                      0.9698
# tone_ewm30                                                                 0.0296
# morning_tone_sum_rs                                                        2.9207
# mins_since_last_news                                                  393507.4829
# tone_mean_ewm_hl15_rs                                   35633555381736755200.0000
# overnight_n                                                               25.8174
# cnt_5m                                                                     0.4706
# overnight_tone_mean_rs                                                    48.5377
# n_news_ewm_hl5                                                             0.0566
# morning_source_div                                                         1.5331
# tone_ewm30_rs                                 195257691556317393569968029696.0000
# overnight_source_div_rs                                                    1.1059
# cnt_60m                                                                    2.1797
# morning_n_rs                                                               0.8238
# overnight_tone_mean                                                        0.9684
# overnight_source_div                                                       2.0143
# has_news                                                                   0.0927
# morning_tone_mean_rs                                                       3.5232
# minute_of_day_1based                                                      54.5589
# tone_ewm15_rs                  11923057859646597935309975159547204842330497278...
# tone_mean_delta                                                            0.2193
# surprise_tone_mean                                                         0.1217
# abs_tone_mean                                                              0.1547
# n_pos_raw                                                                  0.1854
# tone_sum                                                                   0.2733
# n_news                                                                     0.2106
# tone_mean                                                                  0.1550
# tone_sum_slog                                                              0.1037
# cnt_60m_rs                                                                 0.6714
# eps_actual_iqr_outlier                                                     0.0000
# shares_out_roll_mean_252                                                   1.0974
# dividend                                                                   0.0423
# eps_estimate_iqr_outlier                                                   0.0000
# div_amount_rz_8                                                            0.0163
# eps_actual_rz_8                                                            0.1153
# eps_estimate                                                               0.1951
# 5d_before_earnings_flag                                                    0.9317
# shares_out_ffill                                                  8941452172.6873
# eps_surp_pct                                                               0.8874
# split_flag                                                                 0.0000
# dividend_iqr_outlier                                                       0.1127
# earnings_flag                                                              0.1313
# shares_out_iqr_outlier                                                     0.1954
# split_mult_iqr_outlier                                                     0.0342
# eps_surp_rz_8                                                              0.2634
# shares_out_roll_z_252                                                      1.4197
# split_ratio_iqr_outlier                                                    0.0342
# div_event_flag                                                             0.1176
# eps_surp_winsor_iqr_outlier                                                0.0242
# shares_out_roll_std_252                                                    0.3633
# split_mult                                                                 0.3418
# split_ratio                                                                0.3418
# eps_surp_pct_final_iqr_outlier                                             0.0242
# eps_surp_winsor                                                            0.8874
# div_negative_flag                                                          0.0000
# eps_surp_pct_calc                                                          0.8844
# div_amount_iqr_outlier                                                     0.1127
# shares_out_nonpos_flag                                                     0.0000
# split_nonpos_flag                                                          0.0342
# shares_out                                                        8941452172.6873
# log_shares_out                                                             1.2374
# eps_surp_pct_final                                                         0.8874
# div_amount                                                                 0.0423
# log_shares_out_iqr_outlier                                                 0.1940
# eps_estimate_rz_8                                                          0.1135
# eps_actual                                                                 0.2048
# y_target                                                                   2.4364
#
#                                                                       min  \
# dow_0                                                              0.0000
# dow_1                                                              0.0000
# dow_2                                                              0.0000
# dow_3                                                              0.0000
# dow_4                                                              0.0000
# dow_5                                                              0.0000
# f_minsin                                                          -0.9469
# f_mincos                                                          -0.9753
# close                                                             63.5610
# f_volu_z_15_clipped                                               -3.0582
# f_volu_z_30_clipped                                               -3.1499
# f_volu_z_5_clipped                                                -1.7877
# f_volu_z_60_clipped                                               -3.0150
# f_volume_norm                                                     -2.1154
# fz_bb_pos                                                         -5.9010
# fz_dev_close_ema20                                               -30.1572
# fz_dev_close_ema200                                              -17.6776
# fz_dev_close_vwap_15                                             -29.4283
# fz_dev_close_vwap_60                                             -19.1221
# fz_dev_tp_ema20                                                  -23.4853
# fz_hl_over_atr20                                                  -6.5396
# fz_hl_range_pct                                                   -3.4757
# fz_lret_15_rolling                                               -26.0483
# fz_lret_1_rolling                                                -23.5077
# fz_lret_30_rolling                                      -90100000000.0000
# fz_lret_5_rolling                                                -20.0558
# fz_lret_60_rolling                                      -86900000000.0000
# fz_macd_hist                                                     -24.4357
# fz_oc_change_pct                                                 -10.3782
# fz_rsi_pos                                                        -7.7561
# fz_spill_AMAT_lret_lag1                                          -24.3371
# fz_spill_AMAT_lret_lag2                                          -24.3371
# fz_spill_AMAT_lret_lag3                                          -24.0892
# fz_spill_AMAT_lret_lag4                                          -24.0892
# fz_spill_AMAT_lret_lag5                                          -24.3576
# fz_spill_AMD_lret_lag1                                           -12.4877
# fz_spill_AMD_lret_lag2                                           -13.0227
# fz_spill_AMD_lret_lag3                                           -13.0227
# fz_spill_AMD_lret_lag4                                           -12.5459
# fz_spill_AMD_lret_lag5                                           -12.5503
# fz_spill_AVGO_lret_lag1                                          -25.7509
# fz_spill_AVGO_lret_lag2                                          -26.5932
# fz_spill_AVGO_lret_lag3                                          -26.5932
# fz_spill_AVGO_lret_lag4                                          -26.5932
# fz_spill_AVGO_lret_lag5                                          -27.0829
# fz_spill_MU_lret_lag1                                            -12.3601
# fz_spill_MU_lret_lag2                                            -12.2460
# fz_spill_MU_lret_lag3                                            -12.4506
# fz_spill_MU_lret_lag4                                            -12.4506
# fz_spill_MU_lret_lag5                                            -12.4506
# fz_spill_NVDA_lret_lag1                                          -13.2458
# fz_spill_NVDA_lret_lag2                                          -13.3797
# fz_spill_NVDA_lret_lag3                                          -13.2458
# fz_spill_NVDA_lret_lag4                                          -13.4072
# fz_spill_NVDA_lret_lag5                                          -13.2458
# fz_vol_15                                                         -6.3474
# fz_vol_30                                                         -9.6579
# fz_vol_5                                                          -3.5859
# fz_vol_60                                                        -15.1016
# fz_vol_ratio_15                                                   -6.4578
# fz_vol_ratio_30                                                   -5.8761
# fz_vol_ratio_5                                                    -7.8416
# fz_vol_ratio_60                                                   -5.1887
# high                                                              63.7300
# hl_range                                                           0.0000
# low                                                               63.5200
# oc_change                                                         -4.0510
# open                                                              63.6000
# rsi_14_clip                                                        8.6005
# vol_15                                                             0.0083
# vol_30                                                             0.0085
# vol_5                                                              0.0025
# vol_60                                                             0.0074
# volu_z_15                                                         -3.0582
# volu_z_30                                                         -3.1499
# volu_z_5                                                          -1.7877
# volu_z_60                                                         -3.0150
# volume                                                             0.0000
# year                                                            2024.0000
# month                                                              1.0000
# day                                                                1.0000
# overnight_n_rs                                                    -9.3254
# mins_since_last_news_rs                                          -10.6675
# tone_mean_ewm_hl15                                                -0.4248
# overnight_tone_sum_rs                                           -395.7458
# minute_cos                                                        -0.9763
# n_news_ewm_hl15_rs                                                -1.2630
# cnt_15m                                                            0.0000
# tone_ewm15                                                        -1.2002
# morning_n                                                          0.0000
# minute_sin                                                        -0.8616
# dow_6                                                              0.0000
# n_news_ewm_hl5_rs                                                 -1.0093
# overnight_tone_sum                                               -68.8910
# morning_tone_sum                                                 -21.3999
# cnt_30m                                                            0.0000
# n_news_ewm_hl15                                                    0.0000
# tone_mean_delta_rs                                              -332.4205
# morning_tone_mean                                                 -7.4074
# morning_source_div_rs                                             -6.2126
# tone_ewm30                                                        -0.6137
# morning_tone_sum_rs                                              -29.9311
# mins_since_last_news                                               0.0000
# tone_mean_ewm_hl15_rs                                -13185088684185.7324
# overnight_n                                                        0.0000
# cnt_5m                                                             0.0000
# overnight_tone_mean_rs                                          -973.0304
# n_news_ewm_hl5                                                     0.0000
# morning_source_div                                                 0.0000
# tone_ewm30_rs                                   -1229221838550521600.0000
# overnight_source_div_rs                                          -10.8380
# cnt_60m                                                            0.0000
# morning_n_rs                                                      -3.8629
# overnight_tone_mean                                               -7.3753
# overnight_source_div                                               0.0000
# has_news                                                           0.0000
# morning_tone_mean_rs                                              -5.9406
# minute_of_day_1based                                             771.0000
# tone_ewm15_rs                  -813661409893489364561017859047686144.0000
# tone_mean_delta                                                   -9.6154
# surprise_tone_mean                                                -3.3916
# abs_tone_mean                                                      0.0000
# n_pos_raw                                                          0.0000
# tone_sum                                                         -11.3496
# n_news                                                             0.0000
# tone_mean                                                         -9.6154
# tone_sum_slog                                                     -2.5136
# cnt_60m_rs                                                        -3.2018
# eps_actual_iqr_outlier                                             0.0000
# shares_out_roll_mean_252                                          19.9211
# dividend                                                           0.0000
# eps_estimate_iqr_outlier                                           0.0000
# div_amount_rz_8                                                    0.0000
# eps_actual_rz_8                                                   -1.7457
# eps_estimate                                                       0.0000
# 5d_before_earnings_flag                                            0.0000
# shares_out_ffill                                           463420992.0000
# eps_surp_pct                                                      -0.5500
# split_flag                                                         1.0000
# dividend_iqr_outlier                                               0.0000
# earnings_flag                                                      0.0000
# shares_out_iqr_outlier                                             0.0000
# split_mult_iqr_outlier                                             0.0000
# eps_surp_rz_8                                                     -1.8211
# shares_out_roll_z_252                                             -1.9109
# split_ratio_iqr_outlier                                            0.0000
# div_event_flag                                                     0.0000
# eps_surp_winsor_iqr_outlier                                        0.0000
# shares_out_roll_std_252                                            0.0040
# split_mult                                                         0.0000
# split_ratio                                                        0.0000
# eps_surp_pct_final_iqr_outlier                                     0.0000
# ...
# shares_out_ffill                            25507000320.0000
# eps_surp_pct                                          3.4500
# split_flag                                            1.0000
# dividend_iqr_outlier                                  1.0000
# earnings_flag                                         1.0000
# shares_out_iqr_outlier                                1.0000
# split_mult_iqr_outlier                                0.0000
# eps_surp_rz_8                                         0.0000
# shares_out_roll_z_252                                 6.3234
# split_ratio_iqr_outlier                               0.0000
# div_event_flag                                        1.0000
# eps_surp_winsor_iqr_outlier                           0.0000
# shares_out_roll_std_252                               1.1507
# split_mult                                            0.0000
# split_ratio                                           0.0000
# eps_surp_pct_final_iqr_outlier                        0.0000
# eps_surp_winsor                                       3.4500
# div_negative_flag                                     0.0000
# eps_surp_pct_calc                                     3.4632
# div_amount_iqr_outlier                                1.0000
# shares_out_nonpos_flag                                0.0000
# split_nonpos_flag                                     1.0000
# shares_out                                  25507000320.0000
# log_shares_out                                       23.9622
# eps_surp_pct_final                                    3.4500
# div_amount                                            0.1150
# log_shares_out_iqr_outlier                            1.0000
# eps_estimate_rz_8                                     0.0000
# eps_actual                                            1.0900
# y_target                                              6.1559
#
#                                                                               max
# dow_0                                                                      1.0000
# dow_1                                                                      1.0000
# dow_2                                                                      1.0000
# dow_3                                                                      1.0000
# dow_4                                                                      1.0000
# dow_5                                                                      0.0000
# f_minsin                                                                  -0.0805
# f_mincos                                                                   0.9968
# close                                                                    373.9500
# f_volu_z_15_clipped                                                        3.6148
# f_volu_z_30_clipped                                                        5.0000
# f_volu_z_5_clipped                                                         1.7889
# f_volu_z_60_clipped                                                        5.0000
# f_volume_norm                                                             10.9268
# fz_bb_pos                                                                  5.7968
# fz_dev_close_ema20                                                        70.6067
# fz_dev_close_ema200                                                       36.4655
# fz_dev_close_vwap_15                                                      64.0905
# fz_dev_close_vwap_60                                                      42.5179
# fz_dev_tp_ema20                                                           73.9809
# fz_hl_over_atr20                                                          50.4106
# fz_hl_range_pct                                                           16.9091
# fz_lret_15_rolling                                                        23.6804
# fz_lret_1_rolling                                                         20.6565
# fz_lret_30_rolling                                                        20.6767
# fz_lret_5_rolling                                                         19.7371
# fz_lret_60_rolling                                                        21.2340
# fz_macd_hist                                                              44.6055
# fz_oc_change_pct                                                           9.9513
# fz_rsi_pos                                                                 7.6595
# fz_spill_AMAT_lret_lag1                                                   21.5122
# fz_spill_AMAT_lret_lag2                                                   21.5122
# fz_spill_AMAT_lret_lag3                                                   21.4024
# fz_spill_AMAT_lret_lag4                                                   21.4024
# fz_spill_AMAT_lret_lag5                                                   21.4996
# fz_spill_AMD_lret_lag1                                                    18.8717
# fz_spill_AMD_lret_lag2                                                    19.3342
# fz_spill_AMD_lret_lag3                                                    19.3382
# fz_spill_AMD_lret_lag4                                                    18.8581
# fz_spill_AMD_lret_lag5                                                    18.8581
# fz_spill_AVGO_lret_lag1                                                   16.5520
# fz_spill_AVGO_lret_lag2                                                   16.5520
# fz_spill_AVGO_lret_lag3                                                   16.5520
# fz_spill_AVGO_lret_lag4                                                   15.4169
# fz_spill_AVGO_lret_lag5                                                   15.4169
# fz_spill_MU_lret_lag1                                                     25.2188
# fz_spill_MU_lret_lag2                                                     24.6931
# fz_spill_MU_lret_lag3                                                     25.2188
# fz_spill_MU_lret_lag4                                                     25.2188
# fz_spill_MU_lret_lag5                                                     25.4963
# fz_spill_NVDA_lret_lag1                                                   19.5426
# fz_spill_NVDA_lret_lag2                                                   20.2118
# fz_spill_NVDA_lret_lag3                                                   19.5426
# fz_spill_NVDA_lret_lag4                                                   19.5426
# fz_spill_NVDA_lret_lag5                                                   19.6047
# fz_vol_15                                                                 34.7416
# fz_vol_30                                                                 60.6427
# fz_vol_5                                                                  37.0493
# fz_vol_60                                                                 83.7865
# fz_vol_ratio_15                                                           77.0856
# fz_vol_ratio_30                                                          121.8841
# fz_vol_ratio_5                                                            63.4226
# fz_vol_ratio_60                                                          145.4445
# high                                                                     374.0600
# hl_range                                                                   8.7200
# low                                                                      373.7120
# oc_change                                                                  8.7150
# open                                                                     373.9400
# rsi_14_clip                                                               92.0191
# vol_15                                                                     1.2230
# vol_30                                                                     0.6960
# vol_5                                                                      2.7342
# vol_60                                                                     0.3720
# volu_z_15                                                                  3.6148
# volu_z_30                                                                  5.2946
# volu_z_5                                                                   1.7889
# volu_z_60                                                                  7.6168
# volume                                                              62648732.0000
# year                                                                    2025.0000
# month                                                                     12.0000
# day                                                                       31.0000
# overnight_n_rs                                                            12.0000
# mins_since_last_news_rs                                                   39.9481
# tone_mean_ewm_hl15                                                         0.3927
# overnight_tone_sum_rs                                                    690.5294
# minute_cos                                                                -0.5075
# n_news_ewm_hl15_rs                                                  96972714.5589
# cnt_15m                                                                   16.0000
# tone_ewm15                                                                 1.0870
# morning_n                                                                 49.0000
# minute_sin                                                                -0.2164
# dow_6                                                                      0.0000
# n_news_ewm_hl5_rs                                   109361099827078615793664.0000
# overnight_tone_sum                                                       157.2292
# morning_tone_sum                                                          56.9731
# cnt_30m                                                                   18.0000
# n_news_ewm_hl15                                                            0.6725
# tone_mean_delta_rs                                                       332.4205
# morning_tone_mean                                                          8.4746
# morning_source_div_rs                                                      6.3399
# tone_ewm30                                                                 0.5610
# morning_tone_sum_rs                                                       85.7533
# mins_since_last_news                                                 1000000.0000
# tone_mean_ewm_hl15_rs                                 2654966704208812179456.0000
# overnight_n                                                              159.0000
# cnt_5m                                                                    16.0000
# overnight_tone_mean_rs                                                  1348.3862
# n_news_ewm_hl5                                                             1.8126
# morning_source_div                                                         7.0000
# tone_ewm30_rs                               14572237462866528915979967135744.0000
# overnight_source_div_rs                                                    8.0000
# cnt_60m                                                                   22.0000
# morning_n_rs                                                               8.0000
# overnight_tone_mean                                                        5.8366
# overnight_source_div                                                       9.0000
# has_news                                                                   1.0000
# morning_tone_mean_rs                                                     106.4662
# minute_of_day_1based                                                     959.0000
# tone_ewm15_rs                  89010374775197805956987635432853795445734236433...
# tone_mean_delta                                                            9.6154
# surprise_tone_mean                                                         4.8780
# abs_tone_mean                                                              9.6154
# n_pos_raw                                                                 14.0000
# tone_sum                                                                  22.1489
# n_news                                                                    14.0000
# tone_mean                                                                  8.6957
# tone_sum_slog                                                              3.1419
# cnt_60m_rs                                                                 9.2877
# eps_actual_iqr_outlier                                                     0.0000
# shares_out_roll_mean_252                                                  23.9370
# dividend                                                                   0.5900
# eps_estimate_iqr_outlier                                                   0.0000
# div_amount_rz_8                                                            0.6745
# eps_actual_rz_8                                                            2.8329
# eps_estimate                                                               2.8600
# 5d_before_earnings_flag                                                    5.0000
# shares_out_ffill                                                 26343299072.0000
# eps_surp_pct                                                              19.7500
# split_flag                                                                 1.0000
# dividend_iqr_outlier                                                       1.0000
# earnings_flag                                                              1.0000
# shares_out_iqr_outlier                                                     1.0000
# split_mult_iqr_outlier                                                     1.0000
# eps_surp_rz_8                                                              8.2384
# shares_out_roll_z_252                                                     12.1699
# split_ratio_iqr_outlier                                                    1.0000
# div_event_flag                                                             1.0000
# eps_surp_winsor_iqr_outlier                                                1.0000
# shares_out_roll_std_252                                                    1.1574
# split_mult                                                                10.0000
# split_ratio                                                               10.0000
# eps_surp_pct_final_iqr_outlier                                             1.0000
# eps_surp_winsor                                                           19.7500
# div_negative_flag                                                          0.0000
# eps_surp_pct_calc                                                         20.1258
# div_amount_iqr_outlier                                                     1.0000
# shares_out_nonpos_flag                                                     0.0000
# split_nonpos_flag                                                          1.0000
# shares_out                                                       26343299072.0000
# log_shares_out                                                            23.9945
# eps_surp_pct_final                                                        19.7500
# div_amount                                                                 0.5900
# log_shares_out_iqr_outlier                                                 1.0000
# eps_estimate_rz_8                                                          3.1331
# eps_actual                                                                 3.0300
# y_target                                                                  20.6565

# %%
X = df_model[feature_cols]
y = df_model['y_target']

print(f"X (Features) shape: {X.shape}")
print(f"y (Target) shape: {y.shape}")
# Out:
# X (Features) shape: (323190, 159)
# y (Target) shape: (323190,)

# %%
split_ratio = 1.0 / 1.5 
split_index = int(len(df_model) * split_ratio)

X_val = X.iloc[:split_index]
y_val = y.iloc[:split_index]

X_test = X.iloc[split_index:]
y_test = y.iloc[split_index:]

print(f"Validation set (X_val, y_val) shape: {X_val.shape}, {y_val.shape}")
print(f"Testing set (X_test, y_test) shape: {X_test.shape}, {y_test.shape}")
# Out:
# Validation set (X_val, y_val) shape: (215460, 159), (215460,)
# Testing set (X_test, y_test) shape: (107730, 159), (107730,)

# %%
# --- 1. Window Param ---
n_splits = 5
n_total_samples = len(X_val)
n_chunks = n_splits + 1

# Make sure every training chunk has at least 1 row
chunk_size = max(1, n_total_samples // n_chunks) 

print(f"--- Preparing {n_splits}-fold Rolling Window Validation ---")
print(f"X_val total rows: {n_total_samples}")
print(f"Rolling window trainin set size (max_train_size): {chunk_size}")

# --- 2. Create CV (TimeSeriesSplit) ---
tscv_rolling = TimeSeriesSplit(
    n_splits=n_splits,
    max_train_size=chunk_size
)

# 3. Create Pipeline
pipe = Pipeline([
    ('scaler', MaxAbsScaler()),
    ('ridge', Ridge())
])

# 4. Param Grid
param_grid = {
    'ridge__alpha': [0.1, 1.0, 10.0, 100.0, 1000.0]
}

# 5. Grid Search
print(f"\n--- Having Grid Search CV on 'X_val' ... ---")
search = GridSearchCV(pipe, param_grid, 
                      cv=tscv_rolling,
                      scoring='neg_mean_squared_error', 
                      n_jobs=-1,
                      verbose=1)
search.fit(X_val, y_val)

# 6. Print Best Result
best_alpha = search.best_params_['ridge__alpha']
best_score = -search.best_score_

print("\n--- COMPLETED! ---")
print(f"Best Alpha (ridge__alpha): {best_alpha}")
print(f"Best MSE: {best_score}")


# Save Model
# joblib.dump(search.best_estimator_, 'best_ridge_pipeline.pkl')
# Out:
# 🧹 Dropping 8 zero-variance cols globally.
# --- Preparing 5-fold Rolling Window Validation ---
# X_val total rows: 215460
# Rolling window trainin set size (max_train_size): 35910
#
# --- Having Grid Search CV on 'X_val' ... ---
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#
# --- COMPLETED! ---
# Best Alpha (ridge__alpha): 1000.0
# Best MSE: 1.5430425472182314e+37

# %%
# 1. 手动去掉全程零方差列
var = X_val.var()
drop_cols = var[var == 0].index.tolist()
print(f"🧹 Dropping {len(drop_cols)} zero-variance cols globally.")
X_val = X_val.drop(columns=drop_cols)

# 2. 定义稳定的 pipeline
pipe = Pipeline([
    ('scaler', MaxAbsScaler()),
    ('ridge', Ridge())
])

# 3. Ridge alpha grid
param_grid = {'ridge__alpha': [0.1, 1.0, 10.0, 100.0, 1000.0, 1e4]}

# 4. TimeSeries CV
tscv = TimeSeriesSplit(n_splits=10)

search = GridSearchCV(
    pipe, param_grid,
    cv=tscv,
    scoring='neg_mean_squared_error',
    n_jobs=-1, verbose=1
)

search.fit(X_val, y_val)

# 6. Print Best Result
best_alpha = search.best_params_['ridge__alpha']
best_score = -search.best_score_

print("\n--- COMPLETED! ---")
print(f"Best Alpha (ridge__alpha): {best_alpha}")
print(f"Best MSE: {best_score}")
# Out:
# 🧹 Dropping 0 zero-variance cols globally.
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
#
# --- COMPLETED! ---
# Best Alpha (ridge__alpha): 10000.0
# Best MSE: 1.137128768895639e+22

# %%
print("--- 正在运行诊断程序：检查零方差列 ---")

# --- 1. 确保 X_val 存在 ---
try:
    X_val
    y_val
except NameError:
    print("*** 错误: 'X_val' 未定义。***")
    print("请先运行 单元格 1、2、3 来创建 'X_val'。")
    # 如果 X_val 不存在，就停止
    raise

# --- 2. 重新创建你的滚动窗口CV ---
n_splits = 5
n_total_samples = len(X_val)
n_chunks = n_splits + 1
chunk_size = max(1, n_total_samples // n_chunks) 

tscv_rolling = TimeSeriesSplit(
    n_splits=n_splits,
    max_train_size=chunk_size
)

print(f"X_val 总行数: {n_total_samples}")
print(f"滚动窗口训练集大小 (max_train_size): {chunk_size} 行")
print("-" * 30)

# --- 3. 循环遍历每一折，找出问题列 ---
# 我们用一个 set 来存储所有出过问题的列名
problem_columns_set = set()
fold_count = 1

for train_index, test_index in tscv_rolling.split(X_val):
    # a. 获取这一折的训练数据
    X_train_chunk = X_val.iloc[train_index]
    
    # b. 计算这一"块"数据中每一列的"标准差" (Standard Deviation)
    chunk_std = X_train_chunk.std()
    
    # c. 找出标准差为 0 (或 NaN) 的列
    constant_cols = chunk_std[ (chunk_std == 0) | (chunk_std.isnull()) ].index.tolist()
    
    if len(constant_cols) > 0:
        print(f"[第 {fold_count}/{n_splits} 折]: ⚠️ 发现 {len(constant_cols)} 个恒定列!")
        # 把这些列名添加到我们的总集合中
        problem_columns_set.update(constant_cols)
    else:
        print(f"[第 {fold_count}/{n_splits} 折]: ✅ 正常。")
    
    fold_count += 1

# --- 4. 打印最终的总结报告 ---
print("\n" + "=" * 30)
print("--- 诊断完成 ---")

if not problem_columns_set:
    print("✅ 恭喜！在任何一折中都没有发现零方差列。")
    print("   (如果之前报错，问题可能出在别处)")
else:
    print(f"🔥 总共在 {len(problem_columns_set)} 个列中发现了问题 (在至少一折中方差为0):")
    
    # 排序后打印
    sorted_problem_cols = sorted(list(problem_columns_set))
    for col_name in sorted_problem_cols:
        print(f"  - {col_name}")

    print("\n这些列 (很可能是基本面或情绪特征) 导致 Scaler 除以零而崩溃。")
    print("使用 'VarianceThreshold(threshold=0.0)' 管道步骤是正确的解决方案。")
# Out:
# --- 正在运行诊断程序：检查零方差列 ---
# X_val 总行数: 215460
# 滚动窗口训练集大小 (max_train_size): 35910 行
# ------------------------------
# [第 1/5 折]: ⚠️ 发现 10 个恒定列!
# [第 2/5 折]: ⚠️ 发现 10 个恒定列!
# [第 3/5 折]: ⚠️ 发现 15 个恒定列!
# [第 4/5 折]: ⚠️ 发现 15 个恒定列!
# [第 5/5 折]: ⚠️ 发现 15 个恒定列!
#
# ==============================
# --- 诊断完成 ---
# 🔥 总共在 15 个列中发现了问题 (在至少一折中方差为0):
#   - div_amount_rz_8
#   - div_negative_flag
#   - eps_actual_iqr_outlier
#   - eps_actual_rz_8
#   - eps_estimate_iqr_outlier
#   - eps_estimate_rz_8
#   - eps_surp_pct_final_iqr_outlier
#   - eps_surp_winsor_iqr_outlier
#   - shares_out_nonpos_flag
#   - split_flag
#   - split_mult
#   - split_mult_iqr_outlier
#   - split_nonpos_flag
#   - split_ratio
#   - split_ratio_iqr_outlier
#
# 这些列 (很可能是基本面或情绪特征) 导致 Scaler 除以零而崩溃。
# 使用 'VarianceThreshold(threshold=0.0)' 管道步骤是正确的解决方案。
